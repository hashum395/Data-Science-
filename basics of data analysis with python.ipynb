# %%
import pandas as pd
url='https://data.cityofchicago.org/resource/jcxq-k9xf.csv'
df=pd.read_csv(url)
path1=r"D:\file.csv"
df.to_csv(path1)
df
# Out:
#       ca     community_area_name  percent_of_housing_crowded  \
# 0    1.0             Rogers Park                         7.7
# 1    2.0              West Ridge                         7.8
# 2    3.0                  Uptown                         3.8
# 3    4.0          Lincoln Square                         3.4
# 4    5.0            North Center                         0.3
# 5    6.0               Lake View                         1.1
# 6    7.0            Lincoln Park                         0.8
# 7    8.0         Near North Side                         1.9
# 8    9.0             Edison Park                         1.1
# 9   10.0            Norwood Park                         2.0
# 10  11.0          Jefferson Park                         2.7
# 11  12.0             Forest Glen                         1.1
# 12  13.0              North Park                         3.9
# 13  14.0             Albany Park                        11.3
# ...

# %%
# for extract the dataframe and save into our computer
#path="D:\hashum.csv"
sd=df.to_csv('d:\hashum22.csv',index=False)
print(sf)
# Out:
# None

# %%
 #by default they print first row
df.head()
# print first 20 row
fdf.head(20)
#print last 20 row
df.tail(20)

# %%
# get the column name
import pandas as pd
url='https://data.cityofchicago.org/resource/jcxq-k9xf.csv'
df=pd.read_csv(url)
for i in df.columns:
      print(i)

# %%
#replace the column names with our column name
list1=["name","roll","goal","mole","hole","fole","pilo","ssss","ss"] #column numbers equal hny chayia km ya zda hoy to error dy ga
df.columns=list1
df.head()

# %%
         #print without column name
df=pd.read_csv(url,header=None)
df
# Out:
#       0                       1                           2  \
# 0    ca     community_area_name  percent_of_housing_crowded
# 1     1             Rogers Park                         7.7
# 2     2              West Ridge                         7.8
# 3     3                  Uptown                         3.8
# 4     4          Lincoln Square                         3.4
# 5     5            North Center                         0.3
# 6     6               Lake View                         1.1
# 7     7            Lincoln Park                         0.8
# 8     8         Near North Side                         1.9
# 9     9             Edison Park                         1.1
# 10   10            Norwood Park                           2
# 11   11          Jefferson Park                         2.7
# 12   12             Forest Glen                         1.1
# 13   13              North Park                         3.9
# 14   14             Albany Park                        11.3
# ...

# %%
df.loc[2,"community_area_name"]

# %%
df.iloc[2,1]

# %%
df.loc[0:2,"community_area_name":"percent_aged_16_unemployed"]

# %%
x=df[["community_area_name"]]
x

# %%
df["community_area_name"].unique()
