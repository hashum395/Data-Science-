# %%
#Model development(train the model for the prediction)(its is procedure that is used for the development of the product and it continue untill it achieve the target or expection)
# Model define as use the independent variable for calculate dependent variable
# in this i will learn
# 1 simple amd multiple regression
# 2 model evalution using virtualisation
# 3 polynimaial regression and pipeline
# 4 measures for model evalution
# 5 predication and decision making

# here we use for model for determine fair(correct) price for used car
#  the indepentent variable(oilburnamount) use for determine the dependent variable(price)

# %%
# 1 simple and multiple linear regresion   y = mx+c
#                        linear regression show the relationship between a scalar varialbe(a varialbe that contain only one value) and one or more explandatory variable
#                        if explandatory variable is one then is know simple linaer regression if it more than one then it known multiple linear regression
# Explandatory variable(the independent variable is known explandory but it define in two way when a variable is independent its not effected to other)
# when a variable is not indeoent for certain its known explandatory varialble(in defination this is explandatory variable)

# %%
# simple linear regresion
#               use one independent varaible for make predication
#              they have predicator independent variable x and target dependent varaible y
#              y = f(x) + e (we studied in data mining e is error that show difference between stright line and points we know linear regression are show by stright line) 
#              we can be write as y= b0 + b1x (b0 is intercept and b1 is slope)
#
# Multiple linear regression
#              use mulitple linear regression variable for make predication
import pandas as pp
path='https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/DA0101EN/automobileEDA.csv'
df=pp.read_csv(path)
df
# Out:
#      symboling  normalized-losses         make aspiration num-of-doors  \
# 0            3                122  alfa-romero        std          two
# 1            3                122  alfa-romero        std          two
# 2            1                122  alfa-romero        std          two
# 3            2                164         audi        std         four
# 4            2                164         audi        std         four
# 5            2                122         audi        std          two
# 6            1                158         audi        std         four
# 7            1                122         audi        std         four
# 8            1                158         audi      turbo         four
# 9            2                192          bmw        std          two
# 10           0                192          bmw        std         four
# 11           0                188          bmw        std          two
# ...

# %%
# import linear_model  from scikit-learn
from sklearn.linear_model import LinearRegression
lm=LinearRegression() # creat linear regression object(e.g lm) using constructor
x = df[['highway-mpg']] #define predicator variable
y = df[['price']]      #define target variable
lm.fit(x,y)   # use lm.fit() funcation for predication
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
# now we can obtain preication using method predict
lm.predict(x)
# Out:
# array([[16236.50464347],
#        [16236.50464347],
#        [17058.23802179],
#        [13771.3045085 ],
#        [20345.17153508],
#        [17879.97140011],
#        [17879.97140011],
#        [17879.97140011],
#        [21988.63829172],
#        [14593.03788682],
#        [14593.03788682],
#        [15414.77126514],
#        [15414.77126514],
#        [17879.97140011],
#        [20345.17153508],
#        [20345.17153508],
#        [21988.63829172],
#        [-5128.5631929 ],
#        [ 3088.77059031],
#        [ 3088.77059031],
#        [ 4732.23734696],
#        [ 7197.43748192],
#        [13771.3045085 ],
#        [ 7197.43748192],
#        [ 7197.43748192],
#        [ 7197.43748192],
#        [13771.3045085 ],
#        [13771.3045085 ],
#        [18701.70477843],
#        [-5950.29657123],
#        [ 7197.43748192],
#        [ 3910.50396864],
#        [10484.37099521],
#        [10484.37099521],
#        [10484.37099521],
#        [10484.37099521],
#        [11306.10437353],
# ...

# %%
#check intercpt(its is constant(eorr))
lm.intercept_
# Out:
# array([38423.30585816])

# %%
#slope is coef that multiple the independent variable x
lm.coef_
# Out:
# array([[-821.73337832]])

# %%
from sklearn.linear_model import LinearRegression
lm=LinearRegression()
x=df[["highway-mpg"]]
y=df[["price"]]
lm.fit(x,y)
lm.predict(x)
lm.coef_
lm.intercept_
# Out:
# array([38423.30585816])

# %%
# multiple linear reg
# two or more pridicator(x) use for find target variable y
from sklearn.linear_model import LinearRegression      #we know skit learn library is use for machine learning regression(use for regression) and classification(use for high degree polynimial)
lm=LinearRegression()
x=df[["highway-mpg","length", "horsepower"]]
y=df[["price"]]
lm.fit(x,y)
lm.predict(x)
lm.coef_
# Out:
# array([[  102.3722758 , 48838.86708443,   142.33117849]])

# %%
lm.intercept_
# Out:
# array([-45535.28533352])

# %%
# 2 model evalution using virtualisation
# Regression plot(linear regression, polynimial regression) use for estimate the relationship between two variables , know the strength of correlation
# and direction of relationship postive or negative

# x-axis independent variable and y-axis is dependent variable
# for visualation we know library(matplotlib, matplotlib.pylib, seaborn)
import seaborn as sns
sns.regplot(x="highway-mpg" , y="price" , data = df)
#plt.ylim(0,)

# %%
# residual plot show the error between the value attribute( we study in data mining residual is error)
# residual is error between pridicative value and actual result
# we calculate the error= actual result - predictive value
sns.residplot(x="highway-mpg" , y="price" , data = df)


#this plot has curvature(v shape error show) so for this we use nonlinear regression plot(polynomial regression)
#if the residual(error) are show around the strigth line then we linear regression 
# if residual are incresing around the x-axis therefore model is incorrect
#

# %%
#Distribution plot(count the predication value virus actual value this plot is more useful for more then one independent variable)
# this show difference between the actual value to prictive result
actual = sns.distplot(df["price"], hist=False, color="r" , label="actua value" )  # hist= false we not want to see the his if we want to see then put true
pred=lm.predict(x)
pred=  sns.distplot(pred,  hist=False,  color="b",  label="fitted or pred value" , ax=actual)

# this show the our pridiccation is close to the actual value so for this data linear regression/model is good

# %%
import seaborn as sns
#sns.regplot(x="highway-mpg",y="price", data=df)
#sns.residplot(x="highway-mpg",y="price", data=df)
actual= sns.distplot(df["price"],hist=False,color="r",label="actual")
pre=lm.predict(x)
sns.distplot(pre,  hist=False, color="b",label="fitted")

# %%
# 3 polynimaial regression and pipeline(its show the relationship between dependent varaiable x and independent varaible y upto nth degree. its use for nonlinear relationship between x and y))
# when linear model not best for data then we nonlinear model(polynomial model)
# by using the we tranform data into polynomail then we use linear regresion to fit parameter

#its is useful curvatur(v shape plot) relationship
# its is also know General linear regression model(we study in data mining it is use for higher power of the variable like x ki power 2 i.e x^2. if power varaible til 3 then it shap iks cubic)
import numpy as np
x = np.array(df['highway-mpg'])            #we know numpy always using for array and matrix
y = np.array(df['price'])    
a=np.polyfit(x,y,3)                   #this function is for multiple polynomial upto 3 degree
np.poly1d(a)    # ye 1 d ha

#this is use for show the degree of polynomial
# Out:
# poly1d([-1.55663829e+00,  2.04754306e+02, -8.96543312e+03,  1.37923594e+05])

# %%
 #we know skit learn library is use for machine learning regression(use for regression) and classification(use for high degree polynimial regression)
from sklearn.preprocessing import PolynomialFeatures
pr=PolynomialFeatures(degree=3)
x1= df[['highway-mpg']] #define predicator variable
x2 = df[['horsepower']]
pr.fit_transform(x1,x2)        #transfer upto 3 degree we increase the degree we want
 
#Basically polynomial regression decrese the residual(nonlinear to linear) tranform the data and send to linear regression for predication

# steps for Got the pridiction    Normalization(centering)---->Polynomial transform---->Linear Regression

# %%
# steps for Got the pridiction    Normalization(centering)---->Polynomial transform---->Linear Regression

# pipeline (we can simplify the code(above all) by using pipeline library)
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
    #    pipeline=  Normalization(centering)---->Polynomial transform---->Linear Regression
input=[("scale",StandardScaler()),("polynomial",PolynomialFeatures()),("mode",LinearRegression())]
pipe=Pipeline(input)

#example
xa=df[["highway-mpg","horsepower"]]
pipe.fit(xa,y)
pipe.predict(xa)


#so pipeline is best we can do all steps in one step

# %%
# Measures for model evalution(Evaluate the model using numerically and virtualy)
#Numerically(two feature determine the model fit)
# 1 Mean Squre Error(MSE)  (find the MSE calculate the diff=actual value- pred value    and take the square of diff then add all diff(error) divide bt total no of sample)
from sklearn.metrics import mean_squared_error
Y_predict=pipe.predict(xa)
mean_squared_error(df["price"], Y_predict_simple_fit)
# 2 R Squard  (R^2)
# Out:
# /opt/conda/envs/Python36/lib/python3.6/site-packages/sklearn/pipeline.py:331: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   Xt = transform.transform(Xt)
# 16961458.56225057

# %%
# 2 R Squard  (R^2)
x=df[["highway-mpg"]]
y=df[["price"]]
lm.fit(x,y)
lm.score(x,y)

# R square value usually between 0 and 1
# Out:
# 0.4965911884339175

# %%
# 5 predication and decesion making
#  we can take decesion by seeing these parameter
# predicted value make sense
# visualisation
# numercal value for evaluation
# comparing models
